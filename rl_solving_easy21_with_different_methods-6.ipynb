# %% [markdown]
# # Reinforcement Learning Homework
#
# Before you turn this notebook in, make sure everything runs as expected. First, **restart the kernel** (in the menu bar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menu bar, select Cell $\rightarrow$ Run All). You can also perform the two operations in one step (in the menu bar, select Kernel $\rightarrow$ Restart & Run All).
#
# Make sure you fill in any place (or anywhere that you want in the code) that says `YOUR CODE HERE` or "YOUR ANSWER HERE", and remove every line containing the expression: "raise ..." (if you leave such a line your code will not run). This is a reminder for you to complete all parts of the notebook. You can also send an incomplete notebook, but please remove all 'raise'-lines in any case.
#
# You are not required to modify the code where the line `YOUR CODE HERE` does not appear. In fact you can modify the given function and code as you want, at your own risk! Those are just reminders.
#
# Do not remove any cell from the notebook you downloaded. You can add any number of cells (and remove them if not more necessary).
#
# Do not use different packages from the ones that are already imported! (the evaluation may fail otherwise)
#
# Please use only google colab or jupyter to edit this notebook! Other software may save notebooks in a format that may interfere with the evaluation procedure.
#
# ## IMPORTANT: make sure to rerun all the code from the beginning to obtain the results for the final version of your code, since this is the way we will do it before evaluating your notebook!
#
# Fill in your name and ID number (matricola) below:

# %%
NAME = 'Salim Benhamadi'
ID_number = int('2070573')

import IPython
assert IPython.version_info[0] >= 3, "Your version of IPython is too old, please update it."

# %% [markdown]
# ---

# %% [markdown]
# # Homework II - Reinforcement Learning with Jackblack
#
# The following homework allows you to review many concepts from the course of Reinforcement Learning.
#
# In particular you will have to implement Monte Carlo algorithm, SARSA-$\lambda$ and SARSA-$\lambda$ with action-value function approximation. In order to test the implementations, we need an environment. Therefore you need also to complete the given code for a modified version of Blackjack game seen in class, invented by Jack from the car rental. In a burst of creativity, he called it **Jackblack** (with no reference to the actor).
#
# Please, use google colab or jupyter to complete the notebook! Also be sure to deliver the notebook with the correct format (.ipynb). Corrupted notebooks or notebooks with cells missing may not be considered eligible (pun intended) for evaluation.

# %% [markdown]
# Needed imports below.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import seaborn as sns; sns.set()

from copy import deepcopy
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display

random.seed(ID_number)
np.random.seed(ID_number)

# %% [markdown]
# ## Jackblack rules:
#
# - The game is played with an infinite deck of cards (i.e. cards are sampled
# with replacement)
#
#
# - Each draw from the deck results in a value between 1 and 10 (uniformly
# distributed) with a colour of _red_ (probability 1/3) or _black_ (probability
# 2/3).
#
#
# - There are no aces or picture (face) cards in this game (no issues with usable aces!)
#
#
# - At the start of the game both the player and the dealer draw one black
# card (fully observed)
#
#
# - Each turn the player may either **stick** or **hit**:
#     - If the player hits then he draws another card from the deck
#     - If the player sticks he receives no further cards and its turn ends
#
#
# - The values of the player’s cards are added (if black card) or subtracted (if red
# card)
#
#
# - If the player’s sum exceeds 21, or becomes less than 1, then he “goes
# bust” and loses the game, with a reward of -1
#
#
# - If the player sticks then the dealer starts taking turns, same rules apply to him. The dealer always
# sticks on any sum of 17 or greater, and hits otherwise. If the dealer goes
# bust, then the player wins, with a reward of 1; otherwise, the outcome – _win_ (reward 1),
# _lose_ (reward -1), or _draw_ (reward 0) – is given by the player with the largest sum.

# %% [markdown]
# ## Implementation of Jackblack environment
#
# Follow the instructions givenn in each function and implement the missing ones so that the environment will work as expected.
#
# As it usually happens with games, where we receive only a signle reward at the end of the episode, we will assume that there is no discounting, i.e. $\gamma=1$. This will hold throughout the entire notebook (hence you will not see that parameter)!

# %%
class Jackblack():

    def __init__(self):
        """
        Init the environment with its inner variables.
        The first state by picking a random card for the dealer and player.
        """
        dealer_score, _ = self.draw_card()
        player_score, _ = self.draw_card()
        self.state = {"dealer_score": dealer_score, "player_score": player_score}  # initial state
        self.actions = ("hit", "stick")

        init_state = self.state.copy()
        self.history = [init_state]  # game history, recording state and action of each step


    def step(self, action, verbose=True):
        """
        Compute a step in Easy21 game.

        Parameters
        ----------
        action : string, the action to pick
        verbose : bool, if True actions are printed

        Returns
        -------
        state : dict, the new state reached given the picked action
        reward : int, the reward we get in this new state
        done : bool, True if state is terminal, False if not
        """
        #print('ENV STEP ACTION', action)
        self.history.append({"player": action})

        # player hits
        if action == "hit":
            value, colour = self.draw_card()
            self.state['player_score'] = self.compute_new_score(value, colour, self.state['player_score'])
            if verbose:
                print(f'Player draws {colour} {value}')

            new_state = self.state.copy()
            self.history.append(new_state)

            if self.goes_bust(self.state['player_score']):
                # player goes bust
                reward = -1
                if verbose:
                    print('Player goes bust')
                    print('Player loses')
                return self.state, reward, True

            else:
                reward = 0
                return self.state, reward, False

        # player sticks
        else:
            if verbose:
                    print(f'Player stops')
            new_state = self.state.copy()
            self.history.append(new_state)

            state, reward = self.dealer_moves(verbose)
            return self.state, reward, True


    def draw_card(self): # TODO1
        """
        Each draw from the deck results in a value between 1 and 10 (uniformly
        distributed) with a colour of red (probability 1/3) or black (probability 2/3).

        Returns
        -------
        value : int, the value of the card
        colour : string, the colour of the card, "red" or "black"
        """
        # YOUR CODE HERE
        value = random.randint(1, 10)
        colour = np.random.choice(['red','black'], size = 1, p=(1/3,2/3))[0]
        return value, colour


    def goes_bust(self, score): # TODO2
        """
        Check if the player/dealer went bust

        Parameters
        ----------
        score : int, the score to check

        Returns
        -------
        bool : True if score is outside the prescribed range
        """
        # YOUR CODE HERE
        return ((score > 21) or (score < 1))


    def compute_new_score(self, value, colour, current_score): # TODO3
        """
        Compute the new score given the value and the colour of the drawn card.

        Parameters
        ----------
        value : int, the card's value
        colour : string, the card's colour
        current_score : int, the score to update

        Returns
        -------
        new_score : int, updated score
        """
        # YOUR CODE HERE
        if colour == "black":
            new_score = current_score + value
        elif colour == "red":
            new_score = current_score - value
        return new_score


    def dealer_moves(self, verbose=True):
        """
        Fixed dealer policy.

        Parameters
        ----------
        verbose : bool, if True actions are printed

        Returns
        -------
        state : state, the terminal state of the whole game sequence
        reward : int, the reward obtained at the end of the game sequence
        """
        # dealer hits as long as his score is < 17
        while self.state['dealer_score'] < 17:
            value, colour = self.draw_card()
            self.state['dealer_score'] = self.compute_new_score(value, colour, self.state['dealer_score'])
            if verbose:
                print(f'Dealer draws {colour} {value}')

            new_state = self.state.copy()
            self.history.append({"dealer": "hit"})
            self.history.append(new_state)


            if self.goes_bust(self.state['dealer_score']):
                # dealer goes bust, player wins
                if verbose:
                    print('Dealer goes bust')
                    print('Dealer loses')
                reward = 1
                return self.state, reward

        self.history.append({"dealer": "stick"})

        player_score = self.state['player_score']
        dealer_score = self.state['dealer_score']

        # score > 17 -> dealer sticks
        if verbose:
            print('Dealer stops')
        if dealer_score < player_score: # player wins
            reward = 1
            if verbose:
                print('Player wins')
            return self.state, reward
        if dealer_score == player_score: # draw
            reward = 0
            if verbose:
                print('Draw')
            return self.state, reward
        if dealer_score > player_score: # player loses
            reward = -1
            if verbose:
                print('Dealer wins')
            return self.state, reward


    def print_score(self):
        """
        Print the current score of the game, both for player and dealer.
        """
        print('----------------')
        for player in self.state.items():
            print(player[0] + ': ' + str(player[1]))
        print('----------------')

# %%
# AT THIS POINT THE ENVIRONMENT MUST BE COMPLETED!

# %%
def plot_graph(policy, value, title):

  policy = policy.values

  dealer_showing = np.arange(1, 11)
  player_score = np.arange(1, 22)

  matrix = pd.DataFrame(value, columns=dealer_showing, index=player_score)

  fig = plt.figure(figsize=(20,10))
  sns.set()
  ax = sns.heatmap(matrix, annot=policy, fmt="s", cmap='coolwarm')
  ax.xaxis.tick_top()
  ax.set_title(title)

  plt.xlabel("Dealer")
  plt.ylabel("Player")

# %% [markdown]
# Now explore some steps of a Jackblack game to check if the environment is coherent with the given rules. You can run the next cell multiple times.

# %%
env = Jackblack()
env.print_score()
env.step("hit", True)
env.print_score()
env.step("hit", True)
env.print_score()
env.step("stick", True)
env.print_score()
# Out:
# ----------------
# dealer_score: 5
# player_score: 2
# ----------------
# Player draws red 2
# Player goes bust
# Player loses
# ----------------
# dealer_score: 5
# player_score: 0
# ----------------
# Player draws black 10
# ----------------
# dealer_score: 5
# player_score: 10
# ----------------
# Player stops
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# ----------------
# dealer_score: 25
# player_score: 10
# ----------------

# %% [markdown]
# ## Monte-Carlo Control of Jackblack
#
# Let's implement the classical version of Monte Carlo algorithm for action-value functions in order to find a good policy to win over the dealer.
#
# The $\epsilon$-greedy policy should be implemented such that:
# $$ \epsilon = \frac{N_0}{N_0 + c_1}  $$
#
# where $c_1$ is the number of times the state has been encountered so far. You can (should!) try to understand how the parameter $N_0$ works to set a meaningful trade-off between exploration and exploitation.

# %%
class MC_Control():


    def __init__(self, N_0=100, n_episodes=100, lr=None):
        """
        Init the Monte Carlo control class with its inner variables.
        Try to understand how the N_0 parameter works!
        Both the Q-table and the counter are initialized to zero.
        The first episode is played with a random policy.
        """
        self.actions = ("hit", "stick")
        self.N_0 = N_0                  # constant parameter (influence the exploration/exploitation behavior!)
        self.n_episodes = n_episodes    # number of episodes (games) to sample in order to make the agent learn
        self.lr = lr                    # The learning rate: "how much" the Q-function is updated at each step

        self.Q = self.init_to_zeros()   # init Q function to zeros
        self.N = self.init_to_zeros()   # init N to zeros
        self.policy = "random"          # arbitrarily init the MC learning with a random policy


    def learn_q_value_function(self): # TODO4 (see other functions to understand how it should be done!)
        """
        Update the Q-function over all the episodes.
        From the second episode onwards you should use the epsilon greedy policy: see code below in order to
        understand how to do that!
        Pay attention to the <play_episode> function to understand how to implement this one!
        Do not forget to update both the Q-table and the counter.

        Returns
        ----------
        Q : dictionary of dictionaries. Every state is a key, whose value is another dictionary. The latter
        dictionary's keys are the actions, and the values are the Q-values for the corresponding state-action pair.
        {state: (action)}, Q-value for every state-action pair
        """
        # YOUR CODE HERE
        for i in range(self.n_episodes):
          # Running the an episode using the current policy
          episode = self.play_episode()
          # From the second episode onwards stating using the epsilon greedy policy
          self.policy = "e_greedy"
          for step in episode:
              state, action, reward, done = step
              #print('State', state)
              #print('Action', action)
              #print('Reward', reward)
              #  Updatinh the counter over all the episodes.
              self.increment_counter(state, action) # increment state-action counter
              #  Updating the Q-function over all the episodes.
              self.update_Q(state, action, reward)
        return self.Q


    def init_to_zeros(self):
        """
        Used to init the Q-function and the incremental counter N at 0 for every state-action pairs.

        Returns
        ----------
        lookup_table : {state: (action)}, a dictionary of states as keys and dictionaries as value, in which the actions
        are keys and corresponding Q-values are values
        """
        dealer_scores = np.arange(1, 11)
        player_scores = np.arange(1, 22)
        states = [(dealer_score, player_score) for player_score in player_scores for dealer_score in dealer_scores]
        lookup_table = {}
        for state in states:
            lookup_table[state] = {"hit": 0, "stick": 0}  # initialize to 0 the Q-values!

        return lookup_table


    def play_episode(self):
        """
        Run a complete (from the initial state to the terminal state) Jackblack game sequence following the given policy.

        Returns
        ----------
        episode : [(state, action, reward, done)], a list of (state, action, reward, done)
        """
        env = Jackblack()                # init a game sequence
        state = env.state.copy()         # init state
        episode = []                     # list of the steps of the game sequence
        done = False
        while not done:
            # pick an action regarding the current state and policy
            print('STATES', state)
            action = self.get_action(state)
            print('ACTION', action)
            next_state, reward, done = deepcopy(env.step(action))
            step = (state, action, reward, done)  # store previous state
            state = next_state
            episode.append(step)

        return episode


    def update_Q(self, state, action, total_reward):  # TODO5
        """
        Update Q value towards the target.
        Even if this function does not return anything, you need to update <self.Q>!

        Parameters
        ----------
        state : dict, the current state
        action : string, the current action
        reward : int, the reward for that state-action pair
        """
        lookup_state = tuple(state.values())

        # The learning rate, decaying along with the number of times an action-state pair
        # has been explored. It represents the amount of modification we want to bring to
        # the Q value function.
        # YOUR CODE HERE
        alpha = (1 / self.get_state_action_counter(state, action))
        self.Q[lookup_state][action] +=  alpha* (total_reward - self.Q[lookup_state][action])


    def increment_counter(self, state, action):
        """
        Increment N counter for every action-state pair encountered in an episode.

        Parameters
        ----------
        state : dict, the current state
        action : string, the current action
        """
        lookup_state = tuple(state.values())
        self.N[lookup_state][action] += 1


    def random_policy(self):  # TODO6
        """
        Return an action following a random policy (clearly state free).

        Returns
        ----------
        action : string, random action
        """
        # YOUR CODE HERE
        action = random.choice(self.actions)
        return action


    def e_greedy_policy(self, state):  # TODO7
        """
        Return an action given by an epsilon greedy policy. Check all the given functions (also below)!
        They can be of great help!

        Parameters
        ----------
        state : dict, state where we pick the action

        Returns
        ----------
        action : string, action from epsilon greedy policy
        """
        # YOUR CODE HERE
        threshold = self.N_0/(self.N_0 + self.get_state_counter(state))
        if threshold > random.uniform(0, 1):
            action = random.choice(self.actions)
        else:
            action = self.get_action_w_max_value(state)
        return action



    def get_action(self, state):  # TODO8
        """
        Return an action following the policy prescribed by the inner value of the class (either "random" or "e_greedy").
        Use the functions above!

        Parameters
        ----------
        state : dict, state where we pick the action

        Returns
        ----------
        action : string, action from prescribed policy
        """
        # YOUR CODE HERE
        if self.policy == "random":
            action = self.random_policy()
        if self.policy == "e_greedy":
            action = self.e_greedy_policy(state)
        return action


    def get_action_w_max_value(self, state):
        """
        Return the action with the max Q-value at a given state.

        Parameters
        ----------
        state : dict, state for the Q-function

        Returns
        ----------
        action : string, best action for the state according to Q-function
        """
        lookup_state = tuple(state.values())
        list_values = list(self.Q[lookup_state].values())
        if list_values[0] == list_values[1]:
            return self.random_policy()      # randomly breaking ties
        else:
            action = max(self.Q[lookup_state], key=self.Q[lookup_state].get)
            return action


    def get_state_counter(self, state):
        """
        Return the counter for a given state.

        Parameters
        ----------
        state : dict or tuple with values

        Returns
        ----------
        counter : int, the number of times a state has been explored
        """
        try:
            counter = np.sum(list(self.N[state].values()))
        except TypeError:
            lookup_state = tuple(state.values())
            counter = np.sum(list(self.N[lookup_state].values()))

        return counter


    def get_state_action_counter(self, state, action):
        """
        Return the counter for a given action-state pair.

        Parameters
        ----------
        state : dict or tuple with values
        action : string

        Returns
        ----------
        counter : int, the number of times an action-state pair has been explored
        """
        try:
            counter = self.N[state][action]
        except TypeError:
            lookup_state = tuple(state.values())
            counter = self.N[lookup_state][action]

        return counter


    def optimal_policy(self):
        """
        Return the learned value-function and a dataframe with the optimal action for each state.

        Returns
        ----------
        max_Q : nd-array, the value-function
        df_pivot : dataframe, representing the best action for each state
        """
        max_Q = np.ndarray(shape=(21, 10))
        df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
        states = list(self.Q.keys())
        for i in range(len(states)):
            best_action = max(self.Q[states[i]], key=self.Q[states[i]].get)
            max_Q[states[i][1]-1][states[i][0]-1] = max(self.Q[states[i]].values())
            df.loc[i] = (states[i][0], states[i][1], best_action)
        df_pivot = df.pivot(index="player_score", columns="dealer_showing", values="best_action")

        return max_Q, df_pivot


def plot_table(table):
    """
    Plot the given value function in 3D.

    Parameters
    ----------
    table : nd-array, the value-function to be plotted
    """
    fig = plt.figure(figsize=(20,10))
    ax = fig.add_subplot(projection = '3d')
    #ax = fig.gca(projection='3d')
    dealer_showing = np.arange(1, 11)
    player_score = np.arange(1, 22)
    dealer_showing, player_score = np.meshgrid(dealer_showing, player_score)
    # Plot the surface.
    surf = ax.plot_surface(dealer_showing, player_score, table, cmap=cm.coolwarm, linewidth=0, antialiased=False)
    # Customize plot
    ax.set_zlim(-1.01, 1.01)
    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

    plt.xlabel('Dealer showing', fontsize=12)
    plt.ylabel('Player score', fontsize=12)
    plt.title('Value function', fontsize=16)
    plt.xticks(np.arange(1, 11))
    plt.yticks(np.arange(1, 22))

    # Add a color bar which maps values to colors.
    fig.colorbar(surf, shrink=0.5, aspect=5)
    plt.show()


mc = MC_Control(n_episodes=50_000)
mc.learn_q_value_function();
mcvalue, mcpol = mc.optimal_policy()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 11}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 8
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 9
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 9
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 5, 'player_score': 3}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 7
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 7, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 2}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 8, 'player_score': 11}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 8, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 4}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 9, 'player_score': 11}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 9, 'player_score': 13}
# ACTION hit
# Player draws black 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION hit
# Player draws red 3
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 4, 'player_score': 11}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 4, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws red 6
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 14}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Draw
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION hit
# Player draws red 4
# Player goes bust
# Player loses
# STATES {'dealer_score': 6, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws red 8
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws red 10
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 8, 'player_score': 16}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 8, 'player_score': 11}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 1}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 3, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 7
# Dealer draws black 5
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 4}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 9, 'player_score': 14}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 20}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws red 8
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 14}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 21}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 10
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws red 8
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws red 8
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 9, 'player_score': 13}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 9, 'player_score': 21}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 5, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws red 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 16}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 21}
# ACTION hit
# Player draws black 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 3
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 7, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 9
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 4, 'player_score': 14}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION hit
# Player draws red 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws red 7
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 9, 'player_score': 14}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 20}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 9, 'player_score': 21}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 1
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws red 7
# Dealer draws red 1
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 20}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws red 7
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 7
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION hit
# Player draws black 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws red 7
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws black 9
# Dealer stops
# Draw
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 8
# Dealer draws red 1
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws red 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Draw
# STATES {'dealer_score': 1, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws red 7
# Dealer draws red 2
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws red 4
# Player goes bust
# Player loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 8, 'player_score': 16}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws black 6
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION hit
# Player draws black 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws black 6
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws black 10
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Player wins
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 4}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 9, 'player_score': 16}
# ACTION hit
# Player draws black 8
# Player goes bust
# Player loses
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 20}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Player wins
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws red 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 5
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 2, 'player_score': 13}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 9, 'player_score': 11}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 7
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION hit
# Player draws red 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws red 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 7
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws red 8
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 10}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws red 3
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 6
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws red 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 3}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 9
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws red 7
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 9
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws red 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws red 9
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 6
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 7
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 16}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 21}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 8
# Dealer stops
# Draw
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws red 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws black 5
# Dealer draws red 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 12}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 2}
# ACTION hit
# Player draws red 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ...
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 8, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws red 10
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 5
# Dealer stops
# Draw
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 9, 'player_score': 16}
# ACTION hit
# Player draws red 1
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws red 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 8}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 8, 'player_score': 16}
# ACTION hit
# Player draws black 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws red 3
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws red 3
# Dealer draws black 10
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 8, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws red 10
# Dealer draws black 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION hit
# Player draws black 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 9, 'player_score': 10}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 16}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 9, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws red 10
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws black 9
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION hit
# Player draws red 10
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 10
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws red 1
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 7
# Dealer draws black 4
# Dealer draws red 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 8, 'player_score': 16}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws black 5
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws black 5
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws black 7
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 8, 'player_score': 14}
# ACTION hit
# Player draws red 1
# STATES {'dealer_score': 8, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws red 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 8, 'player_score': 21}
# ACTION hit
# Player draws black 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws red 6
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 8, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins

# %% [markdown]
# Now let's play 50_000 episodes and learn the Q-function with the Monte Carlo algorithm!

# %%
mc = MC_Control(n_episodes=50_000)
mc.learn_q_value_function();
mcvalue, mcpol = mc.optimal_policy()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 8, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Player wins
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 1, 'player_score': 17}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 1, 'player_score': 19}
# ACTION hit
# Player draws black 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION hit
# Player draws black 8
# Player goes bust
# Player loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer draws red 9
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws red 7
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 9
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 3}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 16}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws red 7
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 3
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws red 6
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 7
# Dealer draws black 9
# Dealer draws red 6
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws red 1
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 2
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 4, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Draw
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 10, 'player_score': 20}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws red 6
# Dealer draws red 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 9
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 11}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 8, 'player_score': 16}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 8, 'player_score': 18}
# ACTION hit
# Player draws black 9
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 8}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 1
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 7
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws red 6
# Dealer draws red 5
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 10
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 3}
# ACTION hit
# Player draws red 3
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 8}
# ACTION hit
# Player draws red 3
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws red 10
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws red 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 8
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 8}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 8, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws red 6
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer draws black 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws red 1
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 17}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 7, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 10
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 5, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 7, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 3, 'player_score': 11}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 3, 'player_score': 12}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 3, 'player_score': 20}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 9
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 8}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 8, 'player_score': 15}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 8, 'player_score': 21}
# ACTION hit
# Player draws black 2
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 9, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 10
# Dealer draws black 2
# Dealer draws red 10
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 9, 'player_score': 10}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION hit
# Player draws black 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 10
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 9, 'player_score': 19}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 9, 'player_score': 21}
# ACTION hit
# Player draws black 2
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 9
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws red 9
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 8
# Dealer draws black 7
# Dealer draws black 1
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws red 4
# Dealer draws red 3
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 9}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 8, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws red 9
# Dealer draws red 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 12}
# ACTION hit
# Player draws red 3
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws red 6
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION hit
# Player draws red 8
# Player goes bust
# Player loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 9
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 9, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer draws black 10
# Dealer draws black 4
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws red 9
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION hit
# Player draws red 8
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws red 2
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 5}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 3, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 5}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 8, 'player_score': 12}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 8, 'player_score': 14}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 8, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 9}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws black 4
# STATES {'dealer_score': 10, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer stops
# Draw
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 12}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 7, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 10, 'player_score': 18}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 12}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 9, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 10
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws black 6
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 6
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 2, 'player_score': 11}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws red 7
# Dealer draws red 1
# Dealer draws red 4
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws red 6
# STATES {'dealer_score': 10, 'player_score': 1}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 9, 'player_score': 15}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 9, 'player_score': 11}
# ACTION hit
# Player draws red 8
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws red 6
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 9}
# ACTION hit
# Player draws black 10
# STATES {'dealer_score': 9, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 3
# Dealer draws black 9
# Dealer stops
# Player wins
# STATES {'dealer_score': 10, 'player_score': 6}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 1, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION hit
# Player draws black 7
# STATES {'dealer_score': 10, 'player_score': 19}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Player wins
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 6
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 16}
# ACTION hit
# Player draws red 2
# STATES {'dealer_score': 10, 'player_score': 14}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 19}
# ACTION hit
# Player draws black 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 9, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# ...
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 10, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 9, 'player_score': 17}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 7, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 8
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 8
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws red 7
# Dealer draws black 10
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 10}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 7, 'player_score': 19}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 21}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 5}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 9, 'player_score': 14}
# ACTION hit
# Player draws red 7
# STATES {'dealer_score': 9, 'player_score': 7}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 9, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 4, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws red 2
# Dealer draws red 7
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws red 9
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 5}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 9, 'player_score': 8}
# ACTION hit
# Player draws red 5
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 9
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 8}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 10, 'player_score': 16}
# ACTION hit
# Player draws black 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 5
# Dealer draws red 7
# Dealer draws red 7
# Dealer draws black 3
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 2}
# ACTION hit
# Player draws red 6
# Player goes bust
# Player loses
# STATES {'dealer_score': 8, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION hit
# Player draws red 6
# STATES {'dealer_score': 5, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 9
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 2}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 10
# Dealer draws black 5
# Dealer draws red 9
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws red 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 10}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 8, 'player_score': 13}
# ACTION hit
# Player draws black 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 10, 'player_score': 7}
# ACTION hit
# Player draws black 8
# STATES {'dealer_score': 10, 'player_score': 15}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 6}
# ACTION hit
# Player draws red 8
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 9, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws red 9
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws red 9
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 3, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws red 7
# Dealer draws black 10
# Dealer draws black 3
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 2}
# ACTION hit
# Player draws red 7
# Player goes bust
# Player loses
# STATES {'dealer_score': 7, 'player_score': 5}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 7, 'player_score': 8}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 7, 'player_score': 9}
# ACTION hit
# Player draws black 5
# STATES {'dealer_score': 7, 'player_score': 14}
# ACTION hit
# Player draws black 2
# STATES {'dealer_score': 7, 'player_score': 16}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 1
# Dealer draws red 5
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 5}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 9, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 6, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws black 6
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 8, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws red 4
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 8, 'player_score': 3}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws red 10
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 6, 'player_score': 8}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws red 6
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 7, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 2, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 2
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 10}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 5, 'player_score': 11}
# ACTION hit
# Player draws red 4
# STATES {'dealer_score': 5, 'player_score': 7}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 10, 'player_score': 10}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 11}
# ACTION hit
# Player draws black 1
# STATES {'dealer_score': 10, 'player_score': 12}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer draws black 2
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 2, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws black 2
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 7, 'player_score': 3}
# ACTION stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 5, 'player_score': 4}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 3}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 1, 'player_score': 10}
# ACTION stick
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 10, 'player_score': 4}
# ACTION hit
# Player draws black 9
# STATES {'dealer_score': 10, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws black 5
# Dealer draws red 10
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 10}
# ACTION hit
# Player draws black 3
# STATES {'dealer_score': 4, 'player_score': 13}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 1, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 1}
# ACTION stick
# Player stops
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 4, 'player_score': 6}
# ACTION stick
# Player stops
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 7
# Dealer stops
# Dealer wins
# STATES {'dealer_score': 5, 'player_score': 9}
# ACTION stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# STATES {'dealer_score': 3, 'player_score': 6}
# ACTION hit
# Player draws red 10
# Player goes bust
# Player loses

# %% [markdown]
# Display the results!

# %%
plot_graph(mcpol, mcvalue, "MC")
plot_table(mcvalue)

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from torch.distributions import Distribution
Distribution.set_default_validate_args(False)

# Define the PPO components
class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
        self.loss = []

    def clear_memory(self):
        self.actions.clear()
        self.states.clear()
        self.logprobs.clear()
        self.rewards.clear()
        self.is_terminals.clear()
        self.loss.clear()

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_size=32):
        super(ActorCritic, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(state_dim, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, action_dim),
            nn.Softmax(dim=-1)
        )

        # critic: 2 hidden + output
        # self.value_layer = nn.Sequential(...)
        # 3 linear layers
        self.critic = nn.Sequential(
            nn.Linear(state_dim, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, state):
        #features = self.fc(state)
        #print('features', features)
        state = state.float().to(device)
        #print('states got', state)
        action_probs = self.actor(state)
        #print('policy actor got', action_probs)
        action_probs = torch.clamp(action_probs, min=1e-6, max=1.0)  # Clamp to avoid invalid values
        #print('policy actor clamp', action_probs)
        value = self.critic(state)
        return action_probs, value

# PPO agent implementation
class PPO:
    def __init__(self, state_dim, action_dim, lr=0.001, gamma=0.99, clip_epsilon=0.2):
        self.policy = ActorCritic(state_dim, action_dim).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr)
        self.memory = Memory()
        self.gamma = gamma
        self.clip_epsilon = clip_epsilon

    def select_action(self, state):
        #print('SELECT ACTION ', state, torch.from_numpy(state))
        state_tensor = torch.FloatTensor(state).to(device)
        #print()
        #print('state tensor', state_tensor)
        action_probs, _ = self.policy(state_tensor)
        #print('action_probs', action_probs)
        #print()
        dist = Categorical(action_probs)
        action = dist.sample()
        self.memory.states.append(state_tensor)
        self.memory.actions.append(action)
        self.memory.logprobs.append(dist.log_prob(action))
        return action.item()

    def update(self):
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.memory.rewards), reversed(self.memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + self.gamma * discounted_reward
            rewards.insert(0, discounted_reward)

        rewards = torch.tensor(rewards, dtype=torch.float).to(device)
        #print('REWARDS', rewards, torch.var_mean(rewards, dim=-1, unbiased=False, keepdim=True)[0])
        #print(rewards.std())
        #print()
        rewards = (rewards - rewards.mean()) / (torch.var_mean(rewards, dim=-1, unbiased=False, keepdim=True)[-1] + 1e-8)  # Prevent division by zero

        old_states = torch.stack(self.memory.states).detach()
        old_actions = torch.tensor(self.memory.actions).detach()
        old_logprobs = torch.tensor(self.memory.logprobs).detach()

        for _ in range(5):  # Number of PPO updates
            action_probs, state_values = self.policy(old_states)
            action_probs = torch.clamp(action_probs, min=1e-6, max=1.0)  # Clamp again for safety
            dist = Categorical(action_probs)
            logprobs = dist.log_prob(old_actions)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            advantages = rewards - state_values.detach().squeeze()

            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1 - self.clip_epsilon, 1 + self.clip_epsilon) * advantages
            loss = -torch.min(surr1, surr2).mean() + 0.5 * (rewards - state_values.squeeze()).pow(2).mean()
            self.memory.loss.append(loss)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        #self.memory.clear_memory()



    def optimal_policy(self):
        """
        Return the learned value-function and a dataframe with the optimal action for each state.

        Returns
        ----------
        max_Q : nd-array, the value-function
        df_pivot : dataframe, representing the best action for each state
        """
        max_Q = np.ndarray(shape=(21, 10))
        df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
        states = list(self.Q.keys())
        for i in range(len(states)):
            #best_action = max(self.Q[states[i]], key=self.Q[states[i]].get)
            action = ppo_agent.select_action(states)
            best_action = env.actions[action]

            max_Q[states[i][1]-1][states[i][0]-1] = max(self.Q[states[i]].values())
            df.loc[i] = (states[i][0], states[i][1], best_action)
        df_pivot = df.pivot(index="player_score", columns="dealer_showing", values="best_action")

        return max_Q, df_pivot


# Training the PPO agent
def train_ppo(env, ppo_agent, max_episodes=1000):
    for episode in range(max_episodes):
        env = Jackblack()                # init a game sequence
        #state = env.state.copy()
        state = np.array(list(env.state.values()), dtype=np.float32)
        print()
        print('START STATES', state)
        total_reward = 0
        done = False
        while not done:
            action = ppo_agent.select_action(state)
            print('ACTION', action, env.actions[action])

            next_state, reward, done = deepcopy(env.step(env.actions[action])) #
            step = (state, action, reward, done)  # store previous state #
            #state = next_state #
            #episode.append(step) #

            #next_state, reward, done = env.step(env.actions[action])
            print('NEXT STATE', next_state, 'REWARD', reward)
            next_state = np.array(list(next_state.values()), dtype=np.float32)

            ppo_agent.memory.rewards.append(reward)
            ppo_agent.memory.is_terminals.append(done)

            state = next_state
            total_reward += reward

            ppo_agent.update()

        if (episode + 1) % 100 == 0:
            print(f"Episode {episode + 1}, Total Reward: {total_reward}")
    return ppo_agent

# %%
# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize environment and PPO agent
env = Jackblack()
state_dim = 2  # "dealer_score" and "player_score"
action_dim = 2  # "hit" or "stick"
ppo_agent = PPO(state_dim, action_dim)

# Train the agent
ppo_agent = train_ppo(env, ppo_agent, max_episodes=5000)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Dealer draws black 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 3} REWARD -1
#
# START STATES [9. 3.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 9, 'player_score': 8} REWARD 0
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': -1} REWARD -1
#
# START STATES [1. 3.]
# ACTION 0 hit
# Player draws red 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': -5} REWARD -1
#
# START STATES [10.  1.]
# ACTION 0 hit
# Player draws red 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 10, 'player_score': -5} REWARD -1
#
# START STATES [7. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 8} REWARD -1
#
# START STATES [8. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 3
# Dealer draws red 3
# Dealer draws red 6
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 3} REWARD 1
#
# START STATES [1. 4.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 1, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 1, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws black 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 25} REWARD -1
#
# START STATES [2. 6.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 2, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 2, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 10
# NEXT STATE {'dealer_score': 2, 'player_score': 3} REWARD 0
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': -6} REWARD -1
#
# START STATES [1. 6.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 1, 'player_score': 8} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 1, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 22} REWARD -1
#
# START STATES [7. 2.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 7, 'player_score': 10} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 10} REWARD -1
#
# START STATES [9. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws black 4
# Dealer draws red 9
# Dealer draws red 2
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -8, 'player_score': 6} REWARD 1
#
# START STATES [9. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 1} REWARD -1
#
# START STATES [8. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 9} REWARD 1
#
# START STATES [9. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 4} REWARD -1
#
# START STATES [5. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 6} REWARD -1
#
# START STATES [7. 1.]
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 7, 'player_score': 5} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 5} REWARD 1
#
# START STATES [1. 1.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': -9} REWARD -1
#
# START STATES [9. 7.]
# ACTION 0 hit
# Player draws red 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': -1} REWARD -1
#
# START STATES [3. 2.]
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 3, 'player_score': 8} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 8} REWARD -1
#
# START STATES [1. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -6, 'player_score': 2} REWARD 1
#
# START STATES [3. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 7} REWARD -1
#
# START STATES [9. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws red 3
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 9} REWARD 1
#
# START STATES [4. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 3} REWARD -1
#
# START STATES [4. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 1} REWARD 1
#
# START STATES [10.  3.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 10, 'player_score': 13} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 13} REWARD -1
#
# START STATES [7. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 9} REWARD 1
#
# START STATES [ 4. 10.]
# ACTION 0 hit
# Player draws red 8
# NEXT STATE {'dealer_score': 4, 'player_score': 2} REWARD 0
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 9} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 4, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 10
# NEXT STATE {'dealer_score': 4, 'player_score': 3} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 3} REWARD 1
#
# START STATES [8. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 5} REWARD -1
#
# START STATES [ 9. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 10} REWARD -1
#
# START STATES [5. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 4} REWARD 1
#
# START STATES [ 4. 10.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 22} REWARD -1
#
# START STATES [3. 7.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 8
# NEXT STATE {'dealer_score': 3, 'player_score': 5} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 3, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': -4} REWARD -1
#
# START STATES [ 4. 10.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 4, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws red 6
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 4, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 25} REWARD -1
#
# START STATES [5. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 5} REWARD 1
#
# START STATES [2. 9.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 24} REWARD -1
#
# START STATES [ 4. 10.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 4, 'player_score': 20} REWARD 0
# ACTION 0 hit
# Player draws black 2
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 22} REWARD -1
#
# START STATES [1. 6.]
# ACTION 0 hit
# Player draws red 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 0} REWARD -1
#
# START STATES [7. 6.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 7, 'player_score': 7} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws black 5
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 7} REWARD 1
#
# START STATES [9. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 9} REWARD -1
#
# START STATES [5. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 8} REWARD -1
#
# START STATES [2. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -7, 'player_score': 1} REWARD 1
#
# START STATES [9. 1.]
# ACTION 0 hit
# Player draws red 3
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': -2} REWARD -1
#
# START STATES [10.  1.]
# ACTION 0 hit
# Player draws red 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 10, 'player_score': -7} REWARD -1
#
# START STATES [ 8. 10.]
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 8, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws red 4
# NEXT STATE {'dealer_score': 8, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws red 9
# NEXT STATE {'dealer_score': 8, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 8, 'player_score': 10} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 10} REWARD 1
#
# START STATES [9. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws red 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 9} REWARD 1
#
# START STATES [7. 1.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 7, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws red 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 7, 'player_score': -3} REWARD -1
#
# START STATES [6. 3.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 6, 'player_score': 6} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer draws black 10
# Dealer draws red 7
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 6} REWARD -1
#
# START STATES [8. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws red 10
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 4} REWARD 1
#
# START STATES [4. 9.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 4, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws red 10
# NEXT STATE {'dealer_score': 4, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 4, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws red 8
# NEXT STATE {'dealer_score': 4, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 4, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws black 2
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 23} REWARD -1
#
# START STATES [5. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 1} REWARD 1
#
# START STATES [9. 5.]
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 9, 'player_score': 14} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 14} REWARD -1
#
# START STATES [9. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 3} REWARD -1
#
# START STATES [7. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 3
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 8} REWARD 1
#
# START STATES [8. 4.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 8, 'player_score': -6} REWARD -1
#
# START STATES [3. 8.]
# ACTION 0 hit
# Player draws red 5
# NEXT STATE {'dealer_score': 3, 'player_score': 3} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 3} REWARD -1
#
# START STATES [3. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 5} REWARD 1
#
# START STATES [5. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 3} REWARD 1
#
# START STATES [4. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 4} REWARD 1
#
# START STATES [8. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 5} REWARD -1
#
# START STATES [8. 5.]
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 8, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws red 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 8, 'player_score': -3} REWARD -1
#
# START STATES [1. 9.]
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 1, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 22} REWARD -1
#
# START STATES [ 4. 10.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 4, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 4, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 4, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 25} REWARD -1
#
# START STATES [10.  4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 4} REWARD -1
# Episode 900, Total Reward: -1
#
# START STATES [5. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 8} REWARD -1
#
# START STATES [9. 5.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 9, 'player_score': 10} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 10} REWARD -1
#
# START STATES [10.  9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 9} REWARD -1
#
# START STATES [6. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 5} REWARD 1
#
# START STATES [9. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 7} REWARD 1
#
# START STATES [9. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 21, 'player_score': 3} REWARD -1
#
# START STATES [8. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 5} REWARD -1
#
# START STATES [2. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 8} REWARD -1
#
# START STATES [5. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 8} REWARD 1
#
# START STATES [8. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 6} REWARD -1
#
# START STATES [10.  6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 6} REWARD -1
#
# START STATES [9. 2.]
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 9, 'player_score': 6} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 6} REWARD 1
#
# START STATES [2. 4.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 2, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 2, 'player_score': 12} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 12} REWARD -1
#
# START STATES [5. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 5} REWARD -1
#
# START STATES [1. 6.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 1, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 1, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 1, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws black 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 25} REWARD -1
#
# START STATES [3. 7.]
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': -2} REWARD -1
#
# START STATES [4. 2.]
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 4, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 4, 'player_score': 9} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 4, 'player_score': 9} REWARD 0
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 4, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws black 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 25} REWARD -1
#
# START STATES [9. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 9} REWARD -1
#
# START STATES [10.  4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 4} REWARD -1
#
# START STATES [10.  5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 9
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws red 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 5} REWARD 1
#
# START STATES [6. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 2} REWARD 1
#
# START STATES [ 4. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws red 10
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -6, 'player_score': 10} REWARD 1
#
# START STATES [6. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -5, 'player_score': 9} REWARD 1
#
# START STATES [3. 7.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 3, 'player_score': 8} REWARD 0
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 3, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 3, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 3, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 5
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': 23} REWARD -1
#
# START STATES [3. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 2} REWARD 1
#
# START STATES [2. 1.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': -9} REWARD -1
#
# START STATES [9. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 5} REWARD -1
#
# START STATES [10.  8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 8} REWARD 1
#
# START STATES [8. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 5} REWARD -1
#
# START STATES [6. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 9} REWARD 1
#
# START STATES [10.  3.]
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 10, 'player_score': 7} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 7} REWARD -1
#
# START STATES [9. 4.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 9, 'player_score': 7} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 7} REWARD 1
#
# START STATES [2. 8.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 2, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 2, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 26} REWARD -1
#
# START STATES [6. 5.]
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 6, 'player_score': 3} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws red 10
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 3} REWARD 1
#
# START STATES [3. 1.]
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 3, 'player_score': 7} REWARD 0
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 3, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': 25} REWARD -1
#
# START STATES [2. 8.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 2, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 23} REWARD -1
#
# START STATES [3. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 8} REWARD -1
#
# START STATES [5. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 7} REWARD 1
#
# START STATES [7. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 5} REWARD -1
#
# START STATES [10. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 10} REWARD -1
#
# START STATES [10.  4.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws red 9
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 4} REWARD -1
#
# START STATES [7. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 2} REWARD -1
#
# START STATES [1. 2.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 1, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 1, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 1, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws black 1
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 22} REWARD -1
#
# START STATES [8. 3.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 8, 'player_score': 4} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 4} REWARD -1
#
# START STATES [2. 8.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 2, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 25} REWARD -1
#
# START STATES [4. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws red 6
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 21, 'player_score': 2} REWARD -1
#
# START STATES [2. 9.]
# ACTION 0 hit
# Player draws red 4
# NEXT STATE {'dealer_score': 2, 'player_score': 5} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 5} REWARD 1
#
# START STATES [10.  5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 24, 'player_score': 5} REWARD 1
#
# START STATES [2. 4.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': -6} REWARD -1
#
# START STATES [ 9. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws red 2
# Dealer draws black 6
# Dealer draws red 9
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -7, 'player_score': 10} REWARD 1
#
# START STATES [10. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 10} REWARD 1
#
# START STATES [5. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 7} REWARD 1
#
# START STATES [7. 3.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 7, 'player_score': 11} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 11} REWARD -1
#
# START STATES [10.  5.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 10, 'player_score': 12} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 12} REWARD -1
#
# START STATES [7. 4.]
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 7, 'player_score': 8} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 8} REWARD -1
#
# START STATES [5. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 5} REWARD 1
#
# START STATES [ 9. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 10} REWARD 1
#
# START STATES [10.  3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 3} REWARD -1
#
# START STATES [10.  2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 2} REWARD 1
#
# START STATES [9. 2.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 9, 'player_score': 7} REWARD 0
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 9, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': 25} REWARD -1
#
# START STATES [9. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 2} REWARD -1
#
# START STATES [7. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 8} REWARD 1
#
# START STATES [4. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 7} REWARD 1
#
# START STATES [6. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 7} REWARD -1
#
# START STATES [3. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 2} REWARD -1
#
# START STATES [1. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -5, 'player_score': 1} REWARD 1
#
# START STATES [2. 3.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 2, 'player_score': 5} REWARD 0
# ACTION 0 hit
# Player draws red 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': -1} REWARD -1
#
# START STATES [ 7. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 10} REWARD -1
#
# START STATES [9. 2.]
# ACTION 0 hit
# Player draws red 3
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': -1} REWARD -1
#
# START STATES [1. 3.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 1, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 1, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws red 9
# NEXT STATE {'dealer_score': 1, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 1, 'player_score': 3} REWARD 0
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 1, 'player_score': 12} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 12} REWARD -1
#
# START STATES [5. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws red 1
# Dealer draws black 9
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 25, 'player_score': 2} REWARD 1
#
# START STATES [7. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 9} REWARD -1
#
# START STATES [ 9. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 10} REWARD -1
#
# START STATES [10.  3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 25, 'player_score': 3} REWARD 1
#
# START STATES [6. 5.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 6, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 5
# NEXT STATE {'dealer_score': 6, 'player_score': 8} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 8} REWARD -1
#
# START STATES [4. 5.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 4, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 4, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws black 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 29} REWARD -1
#
# START STATES [2. 3.]
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 2, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws red 6
# NEXT STATE {'dealer_score': 2, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws red 10
# NEXT STATE {'dealer_score': 2, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 2, 'player_score': 3} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 3} REWARD -1
#
# START STATES [10.  4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 4} REWARD -1
#
# START STATES [1. 8.]
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 1, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 1, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 5
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 23} REWARD -1
#
# START STATES [2. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 5} REWARD 1
#
# START STATES [7. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 8} REWARD 1
#
# START STATES [8. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws red 1
# Dealer draws red 4
# Dealer draws black 8
# Dealer draws red 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 9} REWARD 1
#
# START STATES [2. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws red 10
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 7} REWARD -1
#
# START STATES [9. 3.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 9, 'player_score': 4} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 4} REWARD -1
#
# START STATES [8. 8.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 8, 'player_score': 9} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 9} REWARD -1
#
# START STATES [2. 4.]
# ACTION 0 hit
# Player draws red 5
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': -1} REWARD -1
#
# START STATES [2. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 8} REWARD -1
#
# START STATES [4. 3.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 4, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 4, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 23} REWARD -1
#
# START STATES [4. 3.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 4, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 4, 'player_score': 20} REWARD 0
# ACTION 0 hit
# Player draws black 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 28} REWARD -1
#
# START STATES [2. 7.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws red 6
# NEXT STATE {'dealer_score': 2, 'player_score': 9} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws red 4
# NEXT STATE {'dealer_score': 2, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 9
# NEXT STATE {'dealer_score': 2, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 2, 'player_score': 5} REWARD 0
# ACTION 0 hit
# Player draws red 4
# NEXT STATE {'dealer_score': 2, 'player_score': 1} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 2, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 2, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 2, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 2, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 6
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 22} REWARD -1
#
# START STATES [6. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 8} REWARD -1
#
# START STATES [3. 2.]
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 3, 'player_score': 4} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 4} REWARD -1
#
# START STATES [7. 2.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 7, 'player_score': 9} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 9} REWARD -1
#
# START STATES [3. 1.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 4} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -7, 'player_score': 4} REWARD 1
#
# START STATES [4. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 4} REWARD 1
#
# START STATES [9. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 21, 'player_score': 8} REWARD -1
#
# START STATES [4. 9.]
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 4, 'player_score': 6} REWARD 0
# ACTION 0 hit
# Player draws red 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': -2} REWARD -1
#
# START STATES [9. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 9} REWARD -1
#
# START STATES [8. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 3} REWARD 1
#
# START STATES [9. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 5} REWARD 1
# Episode 1000, Total Reward: 1
#
# START STATES [6. 2.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 6, 'player_score': 3} REWARD 0
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 6, 'player_score': 9} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 9} REWARD 1
#
# START STATES [10.  1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 1} REWARD -1
#
# START STATES [8. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 7} REWARD -1
#
# START STATES [10.  4.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 4} REWARD -1
#
# START STATES [4. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 2} REWARD 1
#
# START STATES [6. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 2} REWARD -1
#
# START STATES [8. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 3} REWARD -1
#
# START STATES [10.  6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 6} REWARD -1
#
# START STATES [ 6. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 10
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 10} REWARD -1
#
# START STATES [10.  8.]
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 8} REWARD 1
#
# START STATES [5. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 8} REWARD -1
#
# START STATES [3. 8.]
# ACTION 0 hit
# Player draws red 5
# NEXT STATE {'dealer_score': 3, 'player_score': 3} REWARD 0
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': -6} REWARD -1
#
# START STATES [3. 4.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 3, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 3, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 3, 'player_score': 16} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 3, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws black 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': 23} REWARD -1
#
# START STATES [2. 5.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 2, 'player_score': 8} REWARD 0
# ACTION 0 hit
# Player draws red 7
# NEXT STATE {'dealer_score': 2, 'player_score': 1} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 2, 'player_score': 2} REWARD 0
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 2, 'player_score': 9} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 24} REWARD -1
#
# START STATES [5. 2.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 5, 'player_score': -8} REWARD -1
#
# START STATES [2. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 4
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 9
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 2} REWARD 1
#
# START STATES [8. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 7} REWARD -1
#
# START STATES [3. 3.]
# ACTION 0 hit
# Player draws red 5
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': -2} REWARD -1
#
# START STATES [10.  1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 1} REWARD -1
#
# START STATES [9. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 5} REWARD 1
#
# START STATES [9. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 2} REWARD -1
#
# START STATES [8. 7.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 8, 'player_score': 10} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws red 7
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# ...
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 24, 'player_score': 4} REWARD 1
#
# START STATES [4. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 1} REWARD 1
#
# START STATES [7. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 6} REWARD -1
#
# START STATES [3. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 2} REWARD -1
# Episode 1200, Total Reward: -1
#
# START STATES [5. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws red 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 8} REWARD -1
#
# START STATES [4. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws red 1
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 7} REWARD -1
#
# START STATES [6. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 10
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 21, 'player_score': 3} REWARD -1
#
# START STATES [7. 5.]
# ACTION 0 hit
# Player draws red 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 7, 'player_score': -2} REWARD -1
#
# START STATES [6. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws red 1
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 7} REWARD -1
#
# START STATES [10.  1.]
# ACTION 0 hit
# Player draws red 8
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 10, 'player_score': -7} REWARD -1
#
# START STATES [ 7. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -2, 'player_score': 10} REWARD 1
#
# START STATES [4. 7.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 7} REWARD 1
#
# START STATES [ 9. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 10} REWARD -1
#
# START STATES [6. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 1} REWARD 1
#
# START STATES [5. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 10
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 25, 'player_score': 6} REWARD 1
#
# START STATES [5. 5.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 5, 'player_score': -5} REWARD -1
#
# START STATES [7. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 1} REWARD 1
#
# START STATES [ 1. 10.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 1, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 4
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 1, 'player_score': 22} REWARD -1
#
# START STATES [ 5. 10.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 5, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 5, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws black 2
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 5, 'player_score': 23} REWARD -1
#
# START STATES [10. 10.]
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer draws black 8
# Dealer draws black 4
# Dealer draws black 2
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 10} REWARD -1
#
# START STATES [10.  5.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 5} REWARD -1
#
# START STATES [9. 9.]
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': 0} REWARD -1
#
# START STATES [10.  3.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 10, 'player_score': 10} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 10
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 10} REWARD 1
#
# START STATES [9. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 1} REWARD -1
#
# START STATES [7. 7.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 7, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 7, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 7, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 7, 'player_score': 22} REWARD -1
#
# START STATES [4. 7.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 4, 'player_score': 8} REWARD 0
# ACTION 0 hit
# Player draws red 5
# NEXT STATE {'dealer_score': 4, 'player_score': 3} REWARD 0
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 4, 'player_score': 4} REWARD 0
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 23} REWARD -1
#
# START STATES [10.  8.]
# ACTION 0 hit
# Player draws black 9
# NEXT STATE {'dealer_score': 10, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 4
# NEXT STATE {'dealer_score': 10, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws red 4
# NEXT STATE {'dealer_score': 10, 'player_score': 17} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -6, 'player_score': 17} REWARD 1
#
# START STATES [6. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -4, 'player_score': 3} REWARD 1
#
# START STATES [2. 8.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 2, 'player_score': 13} REWARD 0
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 2, 'player_score': 12} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -8, 'player_score': 12} REWARD 1
#
# START STATES [5. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 2} REWARD 1
#
# START STATES [9. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 6} REWARD -1
#
# START STATES [3. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 4} REWARD -1
#
# START STATES [7. 4.]
# ACTION 1 stick
# Player stops
# Dealer draws red 6
# Dealer draws black 8
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 4} REWARD -1
#
# START STATES [6. 2.]
# ACTION 0 hit
# Player draws black 1
# NEXT STATE {'dealer_score': 6, 'player_score': 3} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws red 8
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 25, 'player_score': 3} REWARD 1
#
# START STATES [2. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 8
# Dealer draws red 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 1} REWARD -1
#
# START STATES [8. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 21, 'player_score': 3} REWARD -1
#
# START STATES [ 5. 10.]
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 5, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws red 9
# NEXT STATE {'dealer_score': 5, 'player_score': 8} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws red 9
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -5, 'player_score': 8} REWARD 1
#
# START STATES [2. 3.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 2, 'player_score': 11} REWARD 0
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 2, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 28} REWARD -1
#
# START STATES [4. 6.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 26, 'player_score': 6} REWARD 1
#
# START STATES [3. 7.]
# ACTION 0 hit
# Player draws red 6
# NEXT STATE {'dealer_score': 3, 'player_score': 1} REWARD 0
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 3, 'player_score': 4} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 4} REWARD -1
#
# START STATES [ 8. 10.]
# ACTION 0 hit
# Player draws black 3
# NEXT STATE {'dealer_score': 8, 'player_score': 13} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 13} REWARD -1
#
# START STATES [7. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 2
# Dealer draws red 2
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 2} REWARD 1
#
# START STATES [7. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 2} REWARD 1
#
# START STATES [8. 4.]
# ACTION 0 hit
# Player draws black 8
# NEXT STATE {'dealer_score': 8, 'player_score': 12} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 12} REWARD 1
#
# START STATES [5. 9.]
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 5, 'player_score': 6} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 5
# Dealer draws black 7
# Dealer draws black 7
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 6} REWARD 1
#
# START STATES [2. 9.]
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 2, 'player_score': 7} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 23, 'player_score': 7} REWARD 1
#
# START STATES [2. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 2} REWARD 1
#
# START STATES [4. 5.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -3, 'player_score': 5} REWARD 1
#
# START STATES [9. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer draws black 3
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 1} REWARD -1
#
# START STATES [4. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 0, 'player_score': 2} REWARD 1
#
# START STATES [10.  5.]
# ACTION 0 hit
# Player draws red 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 10, 'player_score': -4} REWARD -1
#
# START STATES [2. 8.]
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 2, 'player_score': 18} REWARD 0
# ACTION 0 hit
# Player draws black 5
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 2, 'player_score': 23} REWARD -1
#
# START STATES [8. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 9} REWARD -1
#
# START STATES [ 6. 10.]
# ACTION 0 hit
# Player draws red 5
# NEXT STATE {'dealer_score': 6, 'player_score': 5} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -1, 'player_score': 5} REWARD 1
#
# START STATES [7. 8.]
# ACTION 1 stick
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 8} REWARD -1
#
# START STATES [4. 3.]
# ACTION 0 hit
# Player draws red 1
# NEXT STATE {'dealer_score': 4, 'player_score': 2} REWARD 0
# ACTION 0 hit
# Player draws black 10
# NEXT STATE {'dealer_score': 4, 'player_score': 12} REWARD 0
# ACTION 0 hit
# Player draws red 2
# NEXT STATE {'dealer_score': 4, 'player_score': 10} REWARD 0
# ACTION 0 hit
# Player draws black 7
# NEXT STATE {'dealer_score': 4, 'player_score': 17} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 19} REWARD 0
# ACTION 0 hit
# Player draws black 2
# NEXT STATE {'dealer_score': 4, 'player_score': 21} REWARD 0
# ACTION 0 hit
# Player draws black 7
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 4, 'player_score': 28} REWARD -1
#
# START STATES [ 6. 10.]
# ACTION 0 hit
# Player draws black 5
# NEXT STATE {'dealer_score': 6, 'player_score': 15} REWARD 0
# ACTION 0 hit
# Player draws black 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 6, 'player_score': 25} REWARD -1
#
# START STATES [5. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': 22, 'player_score': 3} REWARD 1
#
# START STATES [3. 8.]
# ACTION 0 hit
# Player draws black 6
# NEXT STATE {'dealer_score': 3, 'player_score': 14} REWARD 0
# ACTION 0 hit
# Player draws black 9
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 3, 'player_score': 23} REWARD -1
#
# START STATES [ 9. 10.]
# ACTION 0 hit
# Player draws red 10
# Player goes bust
# Player loses
# NEXT STATE {'dealer_score': 9, 'player_score': 0} REWARD -1
#
# START STATES [3. 2.]
# ACTION 1 stick
# Player stops
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 17, 'player_score': 2} REWARD -1
#
# START STATES [6. 9.]
# ACTION 0 hit
# Player draws red 7
# NEXT STATE {'dealer_score': 6, 'player_score': 2} REWARD 0
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 7
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 19, 'player_score': 2} REWARD -1
#
# START STATES [4. 1.]
# ACTION 1 stick
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws black 3
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 18, 'player_score': 1} REWARD -1
#
# START STATES [8. 9.]
# ACTION 1 stick
# Player stops
# Dealer draws black 4
# Dealer draws red 8
# Dealer draws red 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# NEXT STATE {'dealer_score': -8, 'player_score': 9} REWARD 1
#
# START STATES [7. 3.]
# ACTION 1 stick
# Player stops
# Dealer draws black 9
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws black 8
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# NEXT STATE {'dealer_score': 20, 'player_score': 3} REWARD -1
#
# START STATES [9. 6.]
# ACTION 0 hit
# Player draws red 3
# NEXT STATE {'dealer_score': 9, 'player_score': 3} REWARD 0

# %%
ppo_agent.memory.rewards

# %%
def optimal_policy(ppo_agent):
    env = Jackblack()
    max_Q = np.ndarray(shape=(21, 10))
    df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
    #np.array(list(env.state.values()), dtype=np.float32)
    states = list(np.array(ppo_agent.memory.states, dtype=np.float32)) #list(self.Q.keys())

    for i in range(len(states)):
        #best_action = max(self.Q[states[i]], key=self.Q[states[i]].get)
        action = ppo_agent.select_action(states[i])
        best_action = env.actions[action]

        #max_Q[states[i][1]-1][states[i][0]-1] = max(self.Q[states[i]].values())
        df.loc[i] = (states[i][0], states[i][1], best_action)
    df_pivot = df.pivot(index="player_score", columns="dealer_showing", values="best_action")

    return df_pivot #max_Q,

optimal_policy(ppo_agent)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-358801266783> in <cell line: 19>()
#      17     return df_pivot #max_Q,
#      18
# ---> 19 optimal_policy(ppo_agent)
#
# <ipython-input-21-358801266783> in optimal_policy(ppo_agent)
#       4     df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
#       5     #np.array(list(env.state.values()), dtype=np.float32)
# ----> 6     states = list(np.array(ppo_agent.memory.states, dtype=np.float32)) #list(self.Q.keys())
#       7
#       8     for i in range(len(states)):
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (1955,) + inhomogeneous part.

# %%
list(np.array(ppo_agent.memory.states, dtype=np.float32))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-8dec9ba5d5c8> in <cell line: 1>()
# ----> 1 list(np.array(ppo_agent.memory.states, dtype=np.float32))
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (1955,) + inhomogeneous part.

# %%
var1 = list(np.array(ppo_agent.memory.states, dtype=np.float32))
np.asarray(var1, dtype="object")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d698b5690062> in <cell line: 1>()
# ----> 1 var1 = list(np.array(ppo_agent.memory.states, dtype=np.float32))
#       2 np.asarray(var1, dtype="object")
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (1955,) + inhomogeneous part.

# %%
np.array(list(env.state.values()), dtype=np.float32)
# Out:
# array([9., 7.], dtype=float32)

# %% [markdown]
# ## TD learning with SARSA(λ) in Jackblack
#
# You shall now implement the SARSA(λ) algorithm, also using eligibility traces (both accumulating and replacing). Do you expect it will learn a better value function than Monte Carlo? Let's see. For the code below we can re-use some of the functions from the Monte Carlo implementation (but you should pay attention!).
#
# The function should be implemented such that:
# $$ \alpha = \frac{1}{c_2 + 1} $$
#
# where $c_2$ is the number of times that state-action pair has been encountered so far, and alpha is the learning rate that multiplies the TD error in the update.

# %%
import numpy as np

class SARSA():


    def __init__(self, lamb=.9, N_0=100, n_episodes=100, trace="accumulating"):
        """
        Init the SARSA class with its inner variables.
        Both the Q-table and the counter are initialized to zero.
        """
        self.actions = ("hit", "stick")
        self.lamb = lamb                # lambda parameter of the SARSA algorithm
        self.n_episodes = n_episodes    # number of episodes (games) to sample in order to make the agent learn
        self.N_0 = N_0                  # constant parameter (influence the exploration/exploitation behavior!)
        self.trace = trace

        self.Q = self.init_to_zeros()                    # init Q function to zeros
        self.N = self.init_to_zeros()                    # init the counter traces to zeros
        self.eligibilty_traces = self.init_to_zeros()    # init eligibilty traces to zeros


    def learn_q_value_function(self):
        """
        Update the Q-function over all the episodes.

        Returns
        ----------
        Q : dictionary of dictionaries. Every state is a key, whose value is another dictionary. The latter
        dictionary's keys are the actions, and the values are the Q-values for the corresponding state-action pair.
        {state: (action)}, Q-value for every state-action pair
        """
        for i in range(self.n_episodes):
            self.eligibilty_traces = self.init_to_zeros()    # init eligibilty traces to zeros
            env = Jackblack()                                # init a game sequence
            state = env.state.copy()                         # init state
            action = self.e_greedy_policy(state)             # pick a first action
            self.increment_counter(state, action)

            done = False
            while not done:
                next_state, reward, done = deepcopy(env.step(action))

                if done:
                    next_action = None
                    delta = self.compute_delta(state, action, next_state, next_action, reward)

                else:
                    next_action = self.e_greedy_policy(next_state)
                    delta = self.compute_delta(state, action, next_state, next_action, reward)
                    self.increment_counter(next_state, next_action)

                self.increment_eligibility_traces(state, action)
                self.update_step(delta)

                action = next_action
                state = next_state

        return self.Q


    def init_to_zeros(self):
        """
        Used to init the Q-function and the incremental counter N at 0 for every state-action pairs.

        Returns
        ----------
        lookup_table : {state: (action)}, a dictionary of states as keys and dictionaries as value, in which the actions
        are keys and corresponding Q-values are values
        """
        dealer_scores = np.arange(1, 11)
        player_scores = np.arange(1, 22)
        states = [(dealer_score, player_score) for player_score in player_scores for dealer_score in dealer_scores]
        lookup_table = {}
        for state in states:
            lookup_table[state] = {"hit": 0, "stick": 0}

        return lookup_table


    def update_step(self, delta):  # TODO9
        """
        Update the Q value towards the target, and also the eligibility traces.
        Implement the correct procedure to update the Q-function and the eligibility traces, with given delta.
        Recall that here traces have already been accumulated/replaced, so there is no need to take care of that.

        Parameters
        ----------
        delta : float, the TD error for the current state-action pair
        """
        # Here is where the lambda parameter intervenes. The higher, the slower the eligibility trace
        # associated to a state-action will fade away.
        # YOUR CODE HERE
        for state in self.Q.keys():
            for action in self.actions:
                # Updating the Q value towards the target
                alpha = 1 / (self.get_state_action_counter(state, action) + 1)
                self.Q[state][action] += alpha * delta * self.eligibilty_traces[state][action]
                # Updating the eligibility trace with the given delta
                self.eligibilty_traces[state][action] *= self.lamb


    def compute_delta(self, state, action, next_state, next_action, reward):
        """
        Compute delta, the TD error.

        Parameters
        ----------
        state : dict, the current state
        action : string, the current action
        reward : int, the reward for the current state-action pair
        next_state : dict, the state we end up in after performing the action
        next_action : string, the action we take in next state following the (e_greedy) policy

        Returns
        ----------
        delta : float, the TD error
        """
        lookup_state = tuple(state.values())
        if next_action is None:
            delta = reward - self.Q[lookup_state][action]
        else:
            next_lookup_state = tuple(next_state.values())
            delta = reward + self.Q[next_lookup_state][next_action] - self.Q[lookup_state][action]
        return delta


    def increment_eligibility_traces(self, state, action):  # TODO10
        """
        Replace or accumulate the active trace.
        To choose between accumulating or replacing traces, query the corresponding inner variable of the class,
        and implement the update accordingly.
        You just need to accumulate or replace, the "fading" is taken into account in <update_step>!

        Parameters
        ----------
        state : dict, active state
        action : string, active action
        """
        # YOUR CODE HERE
        lookup_state = tuple(state.values())
        self.eligibilty_traces[lookup_state][action] += 1



    def increment_counter(self, state, action):
        """
        Increment N counter for every action-state pair encountered in an episode.

        Parameters
        ----------
        state : state, the current score
        action : string, the current score
        """
        lookup_state = tuple(state.values())
        self.N[lookup_state][action] += 1


    def random_policy(self):  # TODO11
        """
        Return an action following a random policy (clearly state free).

        Returns
        ----------
        action : string, random action
        """
        # YOUR CODE HERE
        action = random.choice(self.actions)
        return action


    def e_greedy_policy(self, state):  # TODO12
        """
        Return an action given an epsilon greedy policy.

        Parameters
        ----------
        state : dict, state where we pick the action

        Returns
        ----------
        action : string, action from epsilon greedy policy
        """
        # YOUR CODE HERE
        threshold = self.N_0/(self.N_0 + self.get_state_counter(state))
        if threshold > random.uniform(0, 1):
            action = random.choice(self.actions)
        else:
            action = self.get_action_w_max_value(state)
        return action


    def get_action_w_max_value(self, state):
        """
        Return the action with the max Q-value at a given state.

        Parameters
        ----------
        state : dict, state for the Q-function

        Returns
        ----------
        action : string, best action for the state according to Q-function
        """
        lookup_state = tuple(state.values())
        list_values = list(self.Q[lookup_state].values())
        if list_values[0] == list_values[1]:
            return self.random_policy()
        else:
            action = max(self.Q[lookup_state], key=self.Q[lookup_state].get)
            return action


    def get_state_counter(self, state):
        """
        Return the counter for a given state.

        Parameters
        ----------
        state : dict or tuple with values

        Returns
        ----------
        counter : int, the number of times a state has been explored
        """
        try:
            counter = np.sum(list(self.N[state].values()))
        except TypeError:
            lookup_state = tuple(state.values())
            counter = np.sum(list(self.N[lookup_state].values()))

        return counter


    def get_state_action_counter(self, state, action):
        """
        Return the counter for a given action-state pair.

        Parameters
        ----------
        state : dict or tuple with values
        action : string

        Returns
        ----------
        counter : int, the number of times an action-state pair has been explored
        """
        try:
            counter = self.N[state][action]
        except TypeError:
            lookup_state = tuple(state.values())
            counter = self.N[lookup_state][action]

        return counter


    def optimal_policy(self):
        """
        Return the learned value-function and a dataframe with the optimal action for each state.

        Returns
        ----------
        max_Q : nd-array, the value-function
        df_pivot : dataframe, representing the best action for each state
        """
        max_Q = np.ndarray(shape=(21, 10))
        df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
        states = list(self.Q.keys())
        for i in range(len(states)):
            best_action = max(self.Q[states[i]], key=self.Q[states[i]].get)
            max_Q[states[i][1]-1][states[i][0]-1] = max(self.Q[states[i]].values())
            df.loc[i] = (states[i][0], states[i][1], best_action)
        df_pivot = df.pivot("player_score", "dealer_showing", "best_action")

        return max_Q, df_pivot

# %%
# AT THIS POINT THE SARSA CLASS MUST BE COMPLETED!

# %% [markdown]
# Now let's play 50_000 episodes and learn the Q-function with the SARSA algorithm!

# %%
sarsa = SARSA(n_episodes=50_000)
sarsa.learn_q_value_function();
sarsavalue, sarsapol = sarsa.optimal_policy()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Player draws black 6
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player draws red 7
# Player stops
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws red 3
# Player stops
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws black 10
# Player stops
# Dealer draws black 3
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 6
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws black 3
# Player draws black 6
# Player draws red 7
# Player stops
# Dealer draws black 9
# Dealer draws red 10
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player draws black 5
# Player stops
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player draws black 9
# Player draws red 7
# Player stops
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player draws black 8
# Player draws black 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 9
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player draws black 1
# Player stops
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player draws black 3
# Player draws red 6
# Player stops
# Dealer draws red 9
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws red 5
# Player stops
# Dealer draws red 8
# Dealer draws black 3
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws black 6
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws red 6
# Player goes bust
# Player loses
# Player stops
# Dealer draws red 1
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 9
# Dealer draws black 10
# Dealer draws red 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws black 5
# Player stops
# Dealer draws red 4
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player draws black 10
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 3
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws red 8
# Player goes bust
# Player loses
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 7
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws black 10
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws red 3
# Dealer draws red 5
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 5
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player draws black 5
# Player stops
# Dealer draws black 4
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws black 10
# Dealer draws red 4
# Dealer draws red 3
# Dealer draws red 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws red 5
# Player stops
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 3
# Dealer draws red 7
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws red 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player draws red 7
# Player stops
# Dealer draws black 2
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws red 7
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws black 6
# Player draws black 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player draws black 8
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws red 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws red 3
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 10
# Dealer draws black 10
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws red 1
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws red 4
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws black 7
# Player draws black 2
# Player stops
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Player wins
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 2
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 1
# Dealer draws red 10
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws black 5
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 6
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 5
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player draws black 6
# Player draws red 9
# Player stops
# Dealer draws red 3
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player draws black 4
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer draws black 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 3
# Dealer draws red 9
# Dealer draws black 8
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 5
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws red 8
# Dealer draws black 1
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws red 9
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws red 8
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws black 3
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws red 4
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 5
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 3
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 7
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player draws black 3
# Player stops
# Dealer draws black 5
# Dealer draws red 7
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws red 4
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer draws red 1
# Dealer draws black 8
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 2
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer draws red 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player draws black 1
# Player stops
# Dealer draws black 9
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 9
# Dealer draws black 1
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player draws black 7
# Player stops
# Dealer draws black 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws black 5
# Player stops
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 2
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player draws black 2
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws black 4
# Dealer draws red 9
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 7
# Dealer draws black 3
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws red 1
# Dealer draws red 5
# Dealer draws black 10
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 7
# Dealer draws black 5
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws red 1
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 7
# Dealer draws black 3
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws black 8
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws red 8
# Player stops
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 5
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 1
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 10
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws red 9
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player draws red 7
# Player stops
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws red 6
# Dealer draws black 6
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player draws red 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws black 7
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player draws red 2
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 10
# Dealer draws red 10
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player draws black 10
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws red 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player draws black 6
# Player draws black 1
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws black 7
# Player draws red 8
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws black 7
# Player stops
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player draws black 6
# Player stops
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws red 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws red 6
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws red 10
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 10
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws black 9
# Player stops
# Dealer draws red 6
# Dealer draws black 1
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws red 9
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player draws black 5
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws red 8
# Player stops
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 8
# Dealer draws red 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws black 8
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws red 8
# Dealer draws black 8
# Dealer draws red 9
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 3
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws red 7
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 8
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws red 9
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws black 3
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws red 9
# Player goes bust
# Player loses
# Player stops
# Dealer draws red 7
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws red 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player draws black 2
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws black 3
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws red 4
# Player stops
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 10
# Player draws red 5
# Player stops
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws red 9
# Dealer draws black 5
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws red 1
# Dealer draws red 7
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 6
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 2
# Player stops
# Dealer draws red 1
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws black 1
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws red 5
# Player draws black 9
# Player stops
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer draws black 5
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws black 8
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 3
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws red 7
# Dealer draws red 2
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 1
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws black 5
# Player draws black 3
# Player stops
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws red 7
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws red 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 6
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws red 2
# Player stops
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws black 5
# Player stops
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws black 7
# Dealer draws black 1
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player draws black 3
# Player draws black 4
# Player stops
# Dealer draws black 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws red 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player draws red 8
# Player goes bust
# Player loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 4
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 1
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player draws black 5
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws red 2
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 9
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer draws black 8
# Dealer draws red 3
# Dealer draws red 5
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 9
# Player stops
# Dealer draws black 6
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 3
# Dealer draws red 9
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws black 3
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws red 7
# Dealer draws black 7
# Dealer draws red 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws red 6
# Dealer draws black 9
# Dealer draws red 10
# Dealer draws black 9
# Dealer draws red 10
# Dealer draws black 3
# Dealer draws black 7
# Dealer draws red 8
# Dealer draws red 2
# Dealer draws black 4
# Dealer draws black 5
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player draws black 6
# Player stops
# Dealer draws red 4
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws red 8
# Dealer draws black 7
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws red 4
# Player stops
# Dealer draws black 1
# Dealer draws red 8
# Dealer draws black 9
# Dealer draws red 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws red 6
# Dealer draws black 2
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player draws red 3
# Player draws black 9
# Player draws black 1
# Player draws black 6
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws red 8
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 7
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws black 9
# Player draws black 3
# Player stops
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player draws red 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 9
# Dealer draws red 9
# Dealer draws black 1
# Dealer draws red 4
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws black 9
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player draws black 9
# Player stops
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 1
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player draws red 3
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws black 6
# Dealer draws red 10
# Dealer draws red 2
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# ...
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws red 6
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws red 5
# Player stops
# Dealer draws black 8
# Dealer draws red 5
# Dealer draws black 10
# Dealer draws red 3
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player draws black 1
# Player draws red 4
# Player stops
# Dealer draws black 5
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 8
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws red 8
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 4
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws red 5
# Dealer draws black 3
# Dealer draws black 9
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player draws red 9
# Player stops
# Dealer draws black 10
# Dealer draws red 8
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws red 1
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 1
# Dealer draws red 2
# Dealer draws red 1
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws black 10
# Dealer draws black 4
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player draws black 2
# Player draws red 5
# Player stops
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player draws black 6
# Player stops
# Dealer draws red 2
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 5
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 7
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player draws black 3
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player draws black 9
# Player draws black 6
# Player stops
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Player wins
# Player stops
# Dealer draws red 3
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 4
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws red 4
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 9
# Dealer draws black 2
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws black 1
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 4
# Dealer draws black 9
# Dealer draws red 4
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws red 4
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 8
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player draws black 7
# Player draws black 1
# Player draws black 7
# Player draws black 6
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 4
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws black 8
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer draws black 7
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws red 5
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 1
# Dealer draws black 3
# Dealer draws black 2
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws black 3
# Dealer draws black 8
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 3
# Dealer draws black 3
# Dealer draws red 3
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer draws black 10
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws black 5
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws black 5
# Player draws black 9
# Player draws red 1
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws black 3
# Dealer draws red 8
# Dealer draws black 8
# Dealer draws black 1
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws black 4
# Dealer draws red 10
# Dealer draws black 7
# Dealer draws black 4
# Dealer draws red 3
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 3
# Dealer draws black 5
# Dealer draws black 6
# Dealer draws red 10
# Dealer draws black 5
# Dealer draws black 1
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 8
# Dealer draws red 2
# Dealer draws black 2
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 8
# Dealer draws red 1
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer draws red 3
# Dealer draws red 8
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 5
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 5
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 6
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer draws red 4
# Dealer draws red 8
# Dealer draws black 6
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 2
# Dealer draws black 4
# Dealer draws red 2
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 3
# Dealer draws black 9
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws black 8
# Dealer goes bust
# Dealer loses
# Player draws black 10
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 7
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 10
# Dealer draws red 1
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player draws red 3
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 3
# Dealer draws red 5
# Dealer draws black 2
# Dealer draws black 6
# Dealer draws black 1
# Dealer draws red 1
# Dealer draws red 3
# Dealer draws red 9
# Dealer draws black 10
# Dealer draws red 9
# Dealer draws black 9
# Dealer draws red 3
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws red 2
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws red 8
# Dealer draws red 3
# Dealer draws black 2
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 10
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 6
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer draws red 2
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 6
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws black 6
# Dealer draws black 4
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player draws black 2
# Player draws red 4
# Player stops
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 9
# Dealer draws black 1
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 8
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 7
# Dealer draws red 1
# Dealer draws black 2
# Dealer draws red 8
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws red 3
# Dealer draws black 3
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws black 3
# Dealer draws red 10
# Dealer draws black 5
# Dealer draws black 5
# Dealer draws red 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws red 2
# Dealer draws red 6
# Dealer draws black 7
# Dealer draws black 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 9
# Dealer draws red 1
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player draws black 6
# Player draws black 5
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 5
# Dealer draws black 4
# Dealer draws black 6
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 4
# Dealer draws black 2
# Dealer draws black 9
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws black 6
# Dealer draws black 4
# Dealer draws black 7
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 1
# Dealer draws red 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws black 4
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player draws black 6
# Player stops
# Dealer draws black 4
# Dealer draws black 5
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 8
# Dealer draws black 1
# Dealer draws black 2
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 2
# Dealer draws black 10
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws red 4
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 5
# Dealer draws black 1
# Dealer draws black 1
# Dealer draws black 8
# Dealer draws black 6
# Dealer goes bust
# Dealer loses
# Player draws black 6
# Player stops
# Dealer draws black 9
# Dealer draws black 3
# Dealer stops
# Dealer wins
# Player stops
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player draws black 10
# Player draws black 10
# Player goes bust
# Player loses
# Player stops
# Dealer draws black 8
# Dealer draws black 2
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 3
# Dealer draws black 1
# Dealer draws black 6
# Dealer draws red 8
# Dealer draws black 1
# Dealer draws red 2
# Dealer draws red 7
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 7
# Dealer draws red 4
# Dealer draws red 8
# Dealer draws red 1
# Dealer draws black 7
# Dealer draws black 6
# Dealer draws red 4
# Dealer draws black 3
# Dealer draws red 9
# Dealer draws red 9
# Dealer goes bust
# Dealer loses
# Player stops
# Dealer draws black 4
# Dealer draws black 1
# Dealer draws red 5
# Dealer draws black 5
# Dealer draws black 5
# Dealer stops
# Dealer wins
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ae2b64a3f437> in <cell line: 3>()
#       1 sarsa = SARSA(n_episodes=50_000)
#       2 sarsa.learn_q_value_function();
# ----> 3 sarsavalue, sarsapol = sarsa.optimal_policy()
#
# <ipython-input-9-8c9080ff3d59> in optimal_policy(self)
#     270             max_Q[states[i][1]-1][states[i][0]-1] = max(self.Q[states[i]].values())
#     271             df.loc[i] = (states[i][0], states[i][1], best_action)
# --> 272         df_pivot = df.pivot("player_score", "dealer_showing", "best_action")
#     273
#     274         return max_Q, df_pivot
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %% [markdown]
# Display the results!

# %%
plot_graph(sarsapol, sarsavalue, "SARSA")
plot_table(sarsavalue)

# %% [markdown]
# ## Linear Value Approximation in Jackblack
#
# Even if our environment is not that complicated, and has a very limited number of states and actions, introducing a linear approximation for the Q-function may be beneficial, especially if we restrict the number of episode to 50_000 (which is not that high).
#
# In the code below you shall implement the linear value approximation of the SARSA(λ) algorithm, where features are overlapped! In particular, the tile coding for the player's sum is made of 6 features; each feature is active if the state lies in between the 2 values (extremes included):
#
# $(1, 6), \ (4, 9), \ (7, 12), \ (10, 15), \ (13, 18), \ (16, 21)$
#
# As you see, there are some states in which there is more than one active feature.

# %%
class Value_Approximation():


    def __init__(self, lamb=.9, epsilon=0.05, n_episodes=100, lr=0.01, trace="accumulating"):
        """
        Init the SARSA approximation class with its inner variables.
        Features are created with the given function.
        Here the epsilon and learning rate parameters are given explicitly and fixed.
        Initial weights for the linear function approximation are sampled from a Gaussian.
        Both the Q-table and the counter are initialized to zero.
        """
        self.actions = ("hit", "stick")
        self.lamb = lamb                                  # lambda parameter of the SARSA algorithm
        self.n_episodes = n_episodes                      # number of episodes (games) to sample in order to make the agent learn
        self.trace = trace

        self.features = self.create_features()                        # make features
        self.n_features = len(self.features)
        self.theta = self.init_theta()                                # init theta randomly
        self.eligibilty_traces = np.zeros(self.n_features)            # init eligibilty traces to zeros

        self.alpha = lr
        self.epsilon = epsilon

        # Only used for plot in optimal policy
        self.Q = self.init_to_zeros()


    def learn_q_value_function(self):  # TODO13
        """
        Update the Q-function (i.e. the weights!) towards the target, and also the eligibility traces.
        This function always considers the epsilon greedy policy.
        Compute delta with the function below (to be implemented).
        Both the updates of the weights and eligibility traces are taken into account in <update_step>. Use it!
        """
        for i in range(self.n_episodes):
            self.eligibilty_traces = np.zeros(self.n_features)            # init eligibilty traces to zeros
            env = Jackblack()                                             # init a game sequence
            state = env.state.copy()                                      # init state
            action = self.e_greedy_policy(state)                          # pick a first action

            # YOUR CODE HERE
            done = False
            while not(done):
                next_state, reward, done = deepcopy(env.step(action))

                if done :
                    next_action = None
                    delta = self.compute_delta(state, action, next_state, next_action, reward)

                else:
                    next_action = self.e_greedy_policy(next_state)
                    delta = self.compute_delta(state, action, next_state, next_action, reward)

                self.update_step(delta, state, action)

                action = next_action
                state = next_state

    def init_theta(self):
        """
        Init the weights of the approximation function from a normal centered reduced gaussian distribution

        Returns
        ----------
        theta : nd-array, random weights for the approximation
        """

        mu, sigma = 0, 0.1 # mean and standard deviation
        theta = np.random.normal(mu, sigma, self.n_features)
        return theta


    def init_to_zeros(self):
        """
        Used to init the Q-function and the incremental counter N at 0 for every state-action pairs.

        Returns
        ----------
        lookup_table : {state: (action)}, a dictionary of states as keys and dictionaries as value, in which the actions
        are keys and corresponding Q-values are values
        """
        dealer_scores = np.arange(1, 11)
        player_scores = np.arange(1, 22)
        states = [(dealer_score, player_score) for player_score in player_scores for dealer_score in dealer_scores]
        lookup_table = {}
        for state in states:
            lookup_table[state] = {"hit": 0, "stick": 0}

        return lookup_table


    def create_features(self):
        """
        Create the features for linear function approximation. Overlapping tile coding.

        Returns
        ----------
        features : list of tuples, each tuple is a combination of features (dealer_feature, player_feature, action)
        """

        dealer = [(1, 4), (4, 7), (7, 10)]
        player = [(1, 6), (4, 9), (7, 12), (10, 15), (13, 18), (16, 21)]  # Overlapping features!
        actions = ["hit", "stick"]
        features = []
        for d in dealer:
            for p in player:
                for a in actions:
                    features.append((d, p, a))
        return features


    def update_step(self, delta, state, action):  # TODO14
        """
        Update the weights of the linear function towards the optimality, and also the eligibility traces.
        According to the inner variable of the class, implement the correct version of the trace.
        Here you need to accumulate or replace, but also to implement the "fading" mechanism!

        Parameters
        ----------
        delta : float, the TD error for the given state-action pair
        state : dict, the current state
        action : string, the current action
        """
        lookup_state = tuple(state.values())
        index_associated_features = []
        for i, feature in enumerate(self.features):
            if (feature[0][0] <= lookup_state[0] <= feature[0][1]) and \
               (feature[1][0] <= lookup_state[1] <= feature[1][1]) and \
               (action == feature[2]):
                index_associated_features.append(i)

        # Update eligibility traces here! Both accumulating and replacing version.
        # YOUR CODE HERE
        for i in index_associated_features:
            self.eligibilty_traces[i] = self.lamb * self.eligibilty_traces[i] + 1
            self.theta[i] = self.theta[i] + self.alpha * delta * self.eligibilty_traces[i]


    def compute_delta(self, state, action, next_state, next_action, reward):  # TODO15
        """
        Compute delta, the TD error, with function approximation! You need to use phi (which is given)!
        Recall the formula of the TD error under function approximation.

        Parameters
        ----------
        state : dict, the current state
        action : string, the current action
        reward : int, the reward for the current state-action pair
        next_state : dict, the state we end up in after performing the action
        next_action : string, the action we take in next state following the policy

        Returns
        ----------
        delta : float, the TD error
        """
        lookup_state = tuple(state.values())
        # YOUR CODE HERE
        if next_action is None:
            delta = reward - self.phi(lookup_state, action)
        else:
            next_lookup_state = (next_state["dealer_score"], next_state["player_score"])
            delta = reward + self.phi(next_lookup_state, next_action) - self.phi(lookup_state, action)
        return delta



    def phi(self, state, action):
        """
        The linear function phi, which compute the Q-value for a given state-action pair. Implements tile coding.

        Parameters
        ----------
        state : tuple, the current state
        action : string, the current action

        Returns
        ----------
        q_value: float, the q value associated to a given state-action pair.

        """
        index_associated_features = []
        for i, feature in enumerate(self.features):
            if (feature[0][0] <= state[0] <= feature[0][1]) and \
               (feature[1][0] <= state[1] <= feature[1][1]) and \
               (action == feature[2]):
                index_associated_features.append(i)
        q_value = np.sum(np.take(self.theta, index_associated_features, axis=0))

        return q_value


    def random_policy(self):  # TODO16
        """
        Return an action following a random policy (clearly state free).

        Returns
        ----------
        action : string, random action
        """
        # YOUR CODE HERE
        action = random.choice(self.actions)
        return action


    def e_greedy_policy(self, state):  # TODO17
        """
        Return an action given an epsilon greedy policy.

        Parameters
        ----------
        state : dict, state where we pick the action

        Returns
        ----------
        action : string, action from epsilon greedy policy
        """
        # YOUR CODE HERE
        if self.epsilon > random.uniform(0, 1):
            action = random.choice(self.actions)
        else:
            action = self.get_action_w_max_value(state)

        return action


    def get_action_w_max_value(self, state):
        """
        Return the action with the max Q-value at a given state.

        Parameters
        ----------
        state : dict, state for the Q-function

        Returns
        ----------
        action : string, best action for the state according to the approximated Q-function
        """
        try:
            lookup_state = tuple(state.values())
        except AttributeError:
            lookup_state = state
        if self.phi(lookup_state, "hit") == self.phi(lookup_state, "stick"):
            return self.random_policy()
        else:
            if self.phi(lookup_state, "hit") > self.phi(lookup_state, "stick"):
                return "hit"
            else:
                return "stick"


    def optimal_policy(self):
        """
        Return the learned value-function and a dataframe with the optimal action for each state.
        Note the use of phi!

        Returns
        ----------
        max_Q : nd-array, the value-function
        df_pivot : dataframe, representing the best action for each state
        """
        max_Q = np.ndarray(shape=(21, 10))
        df = pd.DataFrame(columns=["dealer_showing", "player_score", "best_action"])
        states = list(self.Q.keys())
        for i in range(len(states)):
            best_action = self.get_action_w_max_value(states[i])
            max_Q[states[i][1]-1][states[i][0]-1] = self.phi(states[i], best_action)
            df.loc[i] = (states[i][0], states[i][1], best_action)
        df_pivot = df.pivot("player_score", "dealer_showing", "best_action")

        return max_Q, df_pivot

# %%
# AT THIS POINT THE SARSA WITH APPROXIMATION CLASS MUST BE COMPLETED!

# %% [markdown]
# Now let's play 50_000 episodes and learn the approximated Q-function with the SARSA algorithm with function approximation!

# %%
va = Value_Approximation(n_episodes=50_000)
va.learn_q_value_function()
vavalue, vapol = va.optimal_policy()

# %% [markdown]
# Display the results!

# %%
plot_graph(vapol, vavalue, "ValueApprox")
plot_table(vavalue)

# %% [markdown]
# ### TODO18
# Comment the results you obtained with the three different procedures with regard to the optimal policy, the value-function and the computational burden. Do not describe the results, but try to say meaningful things about _why_ you obtained such results.
# You do not need more than 7-10 lines.
#
# Answer in the cell below.

# %%
# YOUR CODE HERE
"""
In this Reinforcement Learning Assignment, we applied 3 different RL methods to a simple card game that we call JackBlack :

   * 1st Method Monte-Carlo Control: Upon implementing the algorithm into our jackblack environment and simulating 50,000 episodes,
 the Monte Carlo algorithm finds us an optimal policy through the iteratively updated action-value function,
 which also converges to optimality. and With a simple visual analysis of the graphs of the state-value functions with the Monte Carlo policy evaluation.
 the value goes up substantially when the player sum is 20 or greater, and with more games played the values of the rest of the states are flattened out ---> The more episodes it samples,
 the better it learns. It might be good in a simple game like JackBlack, however, in deeper environment sampling, 50k or more episodes might be infeasible…

 ---------------------- > To come over this major drawback, we need to start learning from incomplete episodes.

  * 2nd Method TD Learning with Sarsa(lambda) : In this case we  are going look at the Q value one step in the future to update the current Q value towards this future Q value estimation.
  In more simple terms, we adjust our current Q value to better match a future Q value estimation.
Thus, the Q value is updated on the fly, SARSA starts to learn from incomplete episodes and not at the end of the sampled episode like in MCC.
Compared to Monte-Carlo, an agent learning with SARSA doesn’t need to sample as much episodes to converge to the optimal policy thanks to its ability to learn from incomplete episodes.
That’s pretty useful when episodes are very long and sampling to many of them starts to become computationally too intensive.

 ---------------------- > In jackblack, there are 10*21*2 = 420 different state-action pairs. However, in real life, environments often have thousands of possible states and actions or even continuous states and actions domains.
In such environments it is not possible anymore to store or explicitly calculate each state-action combination hence the need of a Q value function approximation to solve the dimensionality problem.

 * 3rd Method Linear Function Approximation  : in the third case we are going to approximate the Q value function, rather than
 computing it for all the possible state-action pairs. The Q value function is not a lookup table anymore, but a function depending on some weights.
 so, we need to learn the best weights to get our approximation function as close as possible to the optimal Q value function which is clear in the obtained result.

"""
